# %%
from src.System import *

# %%
r1=grafeno()
r2=grafeno()

# %%
f=3
#r2.setNewVectors(multV(f,r2.a),multV(f,r2.b))

# %%
r3=superMesh(r2.a,r2.b,[r1])
r3.showme()

# %%
s=system([r1])

# %%
m=[[f,0],[0,f]]

# %%
s.createSuperLattice([[f,0],[0,f]])
# Out:
# 1

# %%
s.show()
# Out:
# Sistema [Grafeno]
# Celda unitaria:
# Espacio Reciproco:
# Calculando...
# ...Pintando capa 1 (Grafeno)
# ...Terminado

# %%
s.SuperRed.printReciprocalSpace(border=1.5)
# Out:
# Calculando...
# ...Pintando capa 1 (Grafeno)
# ...Terminado
# 1
