# %%
from src.Funciones import *

# %%
l1 = grafeno()
l2 = grafeno().mRot(32.2)

# %%
x = calculaPares(l1,l2)

# %%
for a in l1.atms[0]:
    a.color='blue'

# %%
C1= superMesh((60,0),(0,60),[l1,l2])
C1.showme()

# %%
res=top(x)

# %%
print()
muestra(res,l1,l2)
# Out:
# Mejores candidatos para Super-Red:'R1=Grafeno',R2='Grafeno(rot 32.2°)'
#
# +-----------+-----------+-----------+-----------------------+-----------------------+--------------+
# | # de Atms |     T1    |     T2    | Tención/Rotación Red1 | Tención/Rotación Red2 |     Err      |
# +-----------+-----------+-----------+-----------------------+-----------------------+--------------+
# |     52    | |  3   1| | |  1   3| |          0.0%         |          0.0%         | 0.0006491169 |
# |           | | -1   4| | | -3   4| |          0.0°         |        0.00423°       |              |
# |           |           |           |                       |                       |              |
# |    156    | |  2   5| | | -2   7| |         -0.0%         |          0.0%         | 0.0011243034 |
# |           | | -5   7| | | -7   5| |          0.0°         |        0.00423°       |              |
# ...

# %%
m1 = grafeno()
m2 = grafeno().mRot(30)

# %%
x = calculaPares(m1,m2,maxIt=12, eps=0.4)
res=top(x,n=8)
muestra(res,m1,m2)
# Out:
# Mejores candidatos para Super-Red:'R1=Grafeno',R2='Grafeno(rot 30°)'
#
# +-----------+-----------+-----------+-----------------------+-----------------------+--------------+
# | # de Atms |     T1    |     T2    | Tención/Rotación Red1 | Tención/Rotación Red2 |     Err      |
# +-----------+-----------+-----------+-----------------------+-----------------------+--------------+
# |    724    | |  4  11| | | -4  15| |         -0.0%         |         -0.0%         | 0.0906819723 |
# |           | |-11  15| | |-15  11| |          0.0°         |       -0.15828°       |              |
# |           |           |           |                       |                       |              |
# |    724    | | 11   4| | |  4  11| |         -0.0%         |         -0.0%         | 0.0906819723 |
# |           | | -4  15| | |-11  15| |          0.0°         |        0.15828°       |              |
# |           |           |           |                       |                       |              |
# ...
