# %%
from src.System import *

# %%
g1=grafeno()
g2=grafeno().mRot(21.78)
g3=grafeno().mRot(2*(21.78))
g4=grafeno3().mRot(21.78)
g5=grafeno3().mRot(2*(21.78))

# %%
g1.detachment=3.3
g2.detachment=3.3
g3.detachment=18.4
g4.detachment=3.3
g5.detachment=18.4

# %%
s1=system([g1,g2,g3])
s2=system([g1,g2,g5])
s3=system([g1,g4,g3])

# %%
s1.creaSR()
s2.creaSR()
s3.creaSR()
# Out:
# Sistema Hexagonal
# Posibles Matrices de trasformación calculadas:10
# Opción recomendada:
# Matriz de trasformación:
# 	8	-3
# 	3	5
#
# Sistema [Grafeno,Grafeno(rot 21.78°),Grafeno(rot 43.56°)]
# Celda unitaria con 294 átomos:
# Espacio Reciproco:
# Calculando...
# ...Pintando capa 1 (Grafeno)
# ...Pintando capa 2 (Grafeno(rot 21.78°))
# ...Pintando capa 3 (Grafeno(rot 43.56°))
# ...Terminado
# Sistema Hexagonal
# Posibles Matrices de trasformación calculadas:10
# Opción recomendada:
# Matriz de trasformación:
# 	8	-3
# 	3	5
#
# Sistema [Grafeno,Grafeno(rot 21.78°),Grafeno(s3)(rot 43.56°)]
# Celda unitaria con 294 átomos:
# Espacio Reciproco:
# Calculando...
# ...Pintando capa 1 (Grafeno)
# ...Pintando capa 2 (Grafeno(rot 21.78°))
# ...Pintando capa 3 (Grafeno(s3)(rot 43.56°))
# ...Terminado
# Sistema Hexagonal
# Posibles Matrices de trasformación calculadas:10
# Opción recomendada:
# Matriz de trasformación:
# 	8	-3
# 	3	5
#
# ...

# %%
s1.SuperRed.exporta()
s2.SuperRed.exporta()
s3.SuperRed.exporta()
# Out:
# 1

# %%
sa=system([g1,g2])
sa.creaSR()
sb=system([g1,g3])
sb.creaSR()
# Out:
# Sistema Hexagonal
# Posibles Matrices de trasformación calculadas:10
# Opción recomendada:
# Matriz de trasformación:
# 	9	-6
# 	6	3
#
# Sistema [Grafeno,Grafeno(rot 21.78°)]
# Celda unitaria con 252 átomos:
# Espacio Reciproco:
# Calculando...
# ...Pintando capa 1 (Grafeno)
# ...Pintando capa 2 (Grafeno(rot 21.78°))
# ...Terminado
# Sistema Hexagonal
# Posibles Matrices de trasformación calculadas:10
# Opción recomendada:
# Matriz de trasformación:
# 	3	5
# 	-5	8
#
# Sistema [Grafeno,Grafeno(rot 43.56°)]
# Celda unitaria con 196 átomos:
# Espacio Reciproco:
# Calculando...
# ...Pintando capa 1 (Grafeno)
# ...Pintando capa 2 (Grafeno(rot 43.56°))
# ...Terminado
# 0

# %%
sa.muestra()
sb.muestra()
# Out:
# **Opción 1. T <- Matriz loMat[0] del sistema
# Tamaño de los vectores primitivos:|a|=6.4556,|b|=6.4556
# Ángulo entre vectores:120.00°
# +---------------------+-------------+---------------------+-----------------+-----------------+---------+
# |         Red         |      T      |     Deformación     | G de Distorsión |   delta--theta  | #Átomos |
# +---------------------+-------------+---------------------+-----------------+-----------------+---------+
# |                     | |   3   -2| | |     1.0      0.0| |    0.00000000   |  0.000% -- 0.0° |    14   |
# |       Grafeno       | |   2    1| | |     0.0      1.0| |                 |  0.00% -- 0.0°  |         |
# |                     |             |                     |                 |                 |         |
# |                     | |   3   -1| | | 1.00007 -0.00014| |    0.00000000   | 0.000% -- -0.0° |    14   |
# ...

# %%
s1.SuperRed.detachment
# Out:
# 25.0
